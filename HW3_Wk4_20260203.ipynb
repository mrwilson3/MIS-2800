# %% [markdown]
# <a href="https://colab.research.google.com/github/mrwilson3/MIS-2800/blob/main/HW3_Wk4_20260203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file
# started to run SQLite3

# %%
# !pip install ipython-sql prettytable==3.10.1 pandas==2.2.2

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#   Using cached pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# ...
# Using cached pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension (Moved to the next cell for proper execution order)

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
#This line is required so Colab stops acting like Python and acts more
# %load_ext sql
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) table Marketing_Brands already exists
# [SQL: CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 2
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: Marketing_Brands.brand_id
# [SQL: INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketi
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand
SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
SELECT * FROM Marketing_Brands
WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
SELECT brand_name
FROM Marketing_Brands
WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
#Block 7
# %%sql
SELECT * FROM Marketing_Brands
WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_type = 'Snacks'
   OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9
# %%sql
SELECT brand_name, brand_budget
FROM Marketing_Brands
ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# %%sql
CREATE TABLE High_Budget_Brands AS
SELECT *
FROM Marketing_Brands
WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: Added TABLE
# 2. How did you fix the error in Block #2? Answer: INTO Marketing_Brands
# 3. How did you fix the error in Block #3? Answer: Added *
# 4. How did you fix the error in Block #4? Answer: Listed the columns
# 5. How did you fix the error in Block #5? Answer: Added WHERE brand_type = 'Religious'
# 6. How did you fix the error in Block #6? Answer: Added column + budget filter
# 7. How did you fix the error in Block #7? Answer: Added %%sql
# 8. How did you fix the error in Block #8? Answer: Added Snacks OR Beverages filter
# 9. How did you fix the error in Block #9? Answer: Completed query + ORDER BY DESC
# 10. How did you fix the error in Block #10? Answer: Used CREATE TABLE AS SELECT
